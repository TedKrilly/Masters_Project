# %% [markdown]
# So this file is for getting the relevant CGM data range of values that fall within the measurement window for OGTT, HFMM etc.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from collections import defaultdict
import re

# %%
def simplify_id(id_string):
    # Extract the numeric part
    num_part = re.search(r'\d+', id_string).group()
    # Remove leading zeros
    simplified_num = str(int(num_part))
    # Keep only the last two digits (or one if it's a single digit)
    simplified_num = simplified_num[-2:] if len(simplified_num) > 1 else simplified_num
    return f"Ex{simplified_num}"

# %%
def parse_date_flexible(date_string):
    date_formats = ['%m/%d/%Y', '%d/%m/%Y', '%Y-%m-%d']
    for fmt in date_formats:
        try:
            return datetime.strptime(date_string, fmt)
        except ValueError:
            continue
    raise ValueError(f"Unable to parse date: {date_string}")

# %%
def parse_time_flexible(time_string):
    time_formats = ['%I:%M:%S %p', '%H:%M:%S', '%I:%M %p', '%H:%M']
    for fmt in time_formats:
        try:
            return datetime.strptime(time_string, fmt).time()
        except ValueError:
            continue
    raise ValueError(f"Unable to parse time: {time_string}")

# %%
# Read the input files
time_hfmm = pd.read_csv('Time_OGTT_MMT.csv')
cgm_data = pd.read_csv('CGM_Data_Table.csv')

# %%
# Convert timestamp columns to datetime
cgm_data['Timestamp'] = pd.to_datetime(cgm_data['Timestamp'])

# %%
# Process HFMM data
processed_data = []
missing_cgm_data = []

# %%
for _, row in time_hfmm.iterrows():
    participant_id = row['c11_rand_nr']
    hfmm_date = row['c13_date']
    start_time = row['c13_HFMM_startdrink']
    end_time = row['c13_HFMM_act240']
    
    # Skip if any required data is missing
    if pd.isna(hfmm_date) or pd.isna(start_time) or pd.isna(end_time):
        continue
    
    try:
        hfmm_date = parse_date_flexible(hfmm_date)
        start_time = parse_time_flexible(start_time)
        end_time = parse_time_flexible(end_time)
        
        start_datetime = datetime.combine(hfmm_date, start_time)
        end_datetime = datetime.combine(hfmm_date, end_time)
        
        # Handle case where end time is on the next day
        if end_datetime <= start_datetime:
            end_datetime += timedelta(days=1)
        
        print(f"Processing ID: {participant_id}, HFMM Date: {hfmm_date.date()}")
        
        # Simplify the ID
        simplified_id = simplify_id(participant_id)
        
        # Filter CGM data for this participant and time window
        participant_cgm = cgm_data[
            (cgm_data['Participant'] == participant_id) &
            (cgm_data['Timestamp'] >= start_datetime) &
            (cgm_data['Timestamp'] <= end_datetime)
        ]
        
        print(f"ID {participant_id}: {len(participant_cgm)} CGM readings")
        
        if len(participant_cgm) == 0:
            missing_cgm_data.append(participant_id)
        
        # Process each CGM reading
        for _, cgm_row in participant_cgm.iterrows():
            time_diff = (cgm_row['Timestamp'] - start_datetime).total_seconds() / 60  # Convert to minutes
            processed_data.append({
                'ID': simplified_id,
                'Condition': 'HFMM',
                'test': 'CGM',
                'metab': 'gluc',
                'VAL': cgm_row['Sensor Glucose (mmol/L)'],
                'time': round(time_diff)  # Rounding to nearest minute
            })
    
    except ValueError as e:
        print(f"Error processing ID {participant_id}: {str(e)}")

# Create a DataFrame from the processed data
output_df = pd.DataFrame(processed_data)

# Sort the DataFrame by ID and time
output_df = output_df.sort_values(['ID', 'time'])

# Save to CSV
output_df.to_csv('processed_cgm_hfmm_data.csv', index=False)
print("Processed HFMM data saved to processed_cgm_hfmm_data.csv")

# Report on missing CGM data
if missing_cgm_data:
    print("\nParticipants with missing CGM data for HFMM:")
    for participant in missing_cgm_data:
        print(participant)
else:
    print("\nAll participants have CGM data for HFMM")

# Additional analysis
total_participants = time_hfmm['c11_rand_nr'].nunique()
participants_with_data = output_df['ID'].nunique()

print(f"\nTotal participants in Time_OGTT_MMT: {total_participants}")
print(f"Participants with HFMM CGM data: {participants_with_data}")
print(f"Participants missing HFMM CGM data: {total_participants - participants_with_data}")

# Check for participants in Time_OGTT_MMT but not in the final output
time_hfmm_ids = set(simplify_id(id) for id in time_hfmm['c11_rand_nr'])
output_ids = set(output_df['ID'])
missing_ids = time_hfmm_ids - output_ids

if missing_ids:
    print("\nParticipants in Time_OGTT_MMT but not in final output:")
    print(missing_ids)
# Out:
# Processing ID: PS010001, HFMM Date: 2018-07-23
# ID PS010001: 36 CGM readings
# Processing ID: PS010002, HFMM Date: 2019-01-30
# ID PS010002: 47 CGM readings
# Processing ID: PS010003, HFMM Date: 2018-09-25
# ID PS010003: 0 CGM readings
# Processing ID: PS010004, HFMM Date: 2018-11-09
# ID PS010004: 0 CGM readings
# Processing ID: PS010005, HFMM Date: 2018-04-09
# ID PS010005: 0 CGM readings
# Processing ID: PS010007, HFMM Date: 2018-10-29
# ID PS010007: 0 CGM readings
# Processing ID: PS010006, HFMM Date: 2018-10-23
# ID PS010006: 48 CGM readings
# Processing ID: PS010008, HFMM Date: 2018-10-22
# ID PS010008: 48 CGM readings
# Processing ID: PS010010, HFMM Date: 2018-12-11
# ID PS010010: 0 CGM readings
# Error processing ID PS010009: Unable to parse time: -95
# Processing ID: PS010012, HFMM Date: 2018-11-28
# ID PS010012: 0 CGM readings
# Processing ID: PS010014, HFMM Date: 2019-01-16
# ID PS010014: 0 CGM readings
# Processing ID: PS010011, HFMM Date: 2018-04-12
# ID PS010011: 0 CGM readings
# Processing ID: PS010013, HFMM Date: 2019-01-15
# ID PS010013: 47 CGM readings
# Processing ID: PS010043, HFMM Date: 2019-12-11
# ID PS010043: 0 CGM readings
# Processing ID: PS010015, HFMM Date: 2019-04-02
# ID PS010015: 0 CGM readings
# Processing ID: PS010017, HFMM Date: 2019-02-18
# ID PS010017: 49 CGM readings
# Processing ID: PS010016, HFMM Date: 2019-02-19
# ID PS010016: 48 CGM readings
# Processing ID: PS010018, HFMM Date: 2019-02-04
# ID PS010018: 0 CGM readings
# Processing ID: PS010019, HFMM Date: 2019-03-18
# ID PS010019: 46 CGM readings
# Processing ID: PS010020, HFMM Date: 2019-03-27
# ID PS010020: 48 CGM readings
# Processing ID: PS010045, HFMM Date: 2019-12-11
# ID PS010045: 0 CGM readings
# Processing ID: PS010031, HFMM Date: 2019-06-26
# ID PS010031: 47 CGM readings
# Processing ID: PS010021, HFMM Date: 2019-04-24
# ID PS010021: 46 CGM readings
# Processing ID: PS010022, HFMM Date: 2019-05-14
# ID PS010022: 48 CGM readings
# Processing ID: PS010076, HFMM Date: 2020-06-10
# ID PS010076: 0 CGM readings
# Processing ID: PS010024, HFMM Date: 2019-05-14
# ID PS010024: 48 CGM readings
# Processing ID: PS010023, HFMM Date: 2019-08-05
# ID PS010023: 48 CGM readings
# Processing ID: PS010028, HFMM Date: 2019-06-25
# ID PS010028: 0 CGM readings
# Processing ID: PS010027, HFMM Date: 2019-06-24
# ID PS010027: 47 CGM readings
# Processing ID: PS010030, HFMM Date: 2019-07-15
# ID PS010030: 47 CGM readings
# Processing ID: PS010025, HFMM Date: 2019-11-06
# ID PS010025: 0 CGM readings
# Processing ID: PS010032, HFMM Date: 2019-09-07
# ID PS010032: 0 CGM readings
# Processing ID: PS010047, HFMM Date: 2019-11-19
# ID PS010047: 30 CGM readings
# Processing ID: PS010026, HFMM Date: 2019-09-17
# ID PS010026: 47 CGM readings
# Processing ID: PS010035, HFMM Date: 2019-07-30
# ID PS010035: 0 CGM readings
# Processing ID: PS010034, HFMM Date: 2019-07-24
# ID PS010034: 45 CGM readings
# Processing ID: PS010029, HFMM Date: 2019-10-09
# ID PS010029: 0 CGM readings
# Processing ID: PS010033, HFMM Date: 2019-07-15
# ID PS010033: 48 CGM readings
# Processing ID: PS010046, HFMM Date: 2019-11-19
# ID PS010046: 48 CGM readings
# Processing ID: PS010039, HFMM Date: 2019-08-27
# ID PS010039: 0 CGM readings
# Processing ID: PS010036, HFMM Date: 2019-08-20
# ID PS010036: 47 CGM readings
# Processing ID: PS010037, HFMM Date: 2019-10-22
# ID PS010037: 48 CGM readings
# Processing ID: PS010037, HFMM Date: 2019-10-09
# ID PS010037: 0 CGM readings
# Processing ID: PS010040, HFMM Date: 2019-09-30
# ID PS010040: 48 CGM readings
# Processing ID: PS010041, HFMM Date: 2019-10-15
# ID PS010041: 48 CGM readings
# Processing ID: PS010042, HFMM Date: 2019-10-22
# ID PS010042: 0 CGM readings
# Error processing ID PS010044: Unable to parse date: NaN'
# Processing ID: PS010049, HFMM Date: 2019-11-25
# ID PS010049: 45 CGM readings
# Processing ID: PS010048, HFMM Date: 2019-05-11
# ID PS010048: 0 CGM readings
# Processing ID: PS010052, HFMM Date: 2019-11-26
# ID PS010052: 47 CGM readings
# Error processing ID PS010051: Unable to parse date: NaN'
# Processing ID: PS010050, HFMM Date: 2019-03-12
# ID PS010050: 0 CGM readings
# Processing ID: PS010057, HFMM Date: 2020-01-14
# ID PS010057: 47 CGM readings
# Processing ID: PS010075, HFMM Date: 2020-09-15
# ID PS010075: 48 CGM readings
# Processing ID: PS010053, HFMM Date: 2019-12-18
# ID PS010053: 47 CGM readings
# Processing ID: PS010074, HFMM Date: 2020-01-09
# ID PS010074: 0 CGM readings
# Processing ID: PS010054, HFMM Date: 2019-12-17
# ID PS010054: 48 CGM readings
# Processing ID: PS010055, HFMM Date: 2019-03-12
# ID PS010055: 0 CGM readings
# Processing ID: PS010062, HFMM Date: 2020-01-27
# ID PS010062: 0 CGM readings
# Processing ID: PS010064, HFMM Date: 2020-04-02
# ID PS010064: 0 CGM readings
# Processing ID: PS010058, HFMM Date: 2020-01-21
# ID PS010058: 0 CGM readings
# Processing ID: PS010060 , HFMM Date: 2020-01-28
# ID PS010060 : 0 CGM readings
# Processing ID: PS010061, HFMM Date: 2020-04-02
# ID PS010061: 0 CGM readings
# Processing ID: PS010065, HFMM Date: 2020-04-02
# ID PS010065: 0 CGM readings
# Processing ID: PS010063 , HFMM Date: 2020-01-21
# ID PS010063 : 0 CGM readings
# Processing ID: PS010066 , HFMM Date: 2020-03-16
# ID PS010066 : 0 CGM readings
# Processing ID: PS010067, HFMM Date: 2020-03-03
# ID PS010067: 47 CGM readings
# Processing ID: PS010068, HFMM Date: 2020-02-18
# ID PS010068: 48 CGM readings
# Error processing ID PS010070: Unable to parse time: NaN'
# Processing ID: PS010069, HFMM Date: 2020-02-26
# ID PS010069: 0 CGM readings
# Processing ID: PS010071, HFMM Date: 2020-11-08
# ID PS010071: 0 CGM readings
# Processing ID: PS010072, HFMM Date: 2020-08-18
# ID PS010072: 48 CGM readings
# Processing ID: PS010073, HFMM Date: 2020-08-25
# ID PS010073: 0 CGM readings
# Processing ID: PS010077, HFMM Date: 2020-09-29
# ID PS010077: 48 CGM readings
# Processing ID: PS010080, HFMM Date: 2020-11-16
# ID PS010080: 49 CGM readings
# Processing ID: PS010081, HFMM Date: 2020-10-13
# ID PS010081: 0 CGM readings
# Processing ID: PS010078, HFMM Date: 2020-08-09
# ID PS010078: 0 CGM readings
# Processing ID: PS010079, HFMM Date: 2020-09-22
# ID PS010079: 48 CGM readings
# Processing ID: PS010082, HFMM Date: 2020-03-11
# ID PS010082: 0 CGM readings
# Processing ID: PS010083, HFMM Date: 2020-09-11
# ID PS010083: 0 CGM readings
# Processing ID: ps010085, HFMM Date: 2020-09-12
# ID ps010085: 0 CGM readings
# Processing ID: PS010084, HFMM Date: 2020-11-24
# ID PS010084: 0 CGM readings
# Processing ID: ps010086, HFMM Date: 2020-08-12
# ID ps010086: 0 CGM readings
# Processing ID: ps010087, HFMM Date: 2021-11-01
# ID ps010087: 0 CGM readings
# Processing ID: ps010088, HFMM Date: 2020-12-15
# ID ps010088: 0 CGM readings
# Processing ID: ps010089, HFMM Date: 2021-01-20
# ID ps010089: 0 CGM readings
# Processing ID: ps010090, HFMM Date: 2021-01-13
# ID ps010090: 0 CGM readings
# Processing ID: PS010091, HFMM Date: 2021-09-02
# ID PS010091: 0 CGM readings
# Processing ID: PS010092, HFMM Date: 2021-09-02
# ID PS010092: 0 CGM readings
# Processed HFMM data saved to processed_cgm_hfmm_data.csv
#
# Participants with missing CGM data for HFMM:
# PS010003
# PS010004
# PS010005
# PS010007
# PS010010
# PS010012
# PS010014
# PS010011
# PS010043
# PS010015
# PS010018
# PS010045
# PS010076
# PS010028
# PS010025
# PS010032
# PS010035
# PS010029
# PS010039
# PS010037
# PS010042
# PS010048
# PS010050
# PS010074
# PS010055
# PS010062
# PS010064
# PS010058
# PS010060
# PS010061
# PS010065
# PS010063
# PS010066
# PS010069
# PS010071
# PS010073
# PS010081
# PS010078
# PS010082
# PS010083
# ps010085
# PS010084
# ps010086
# ps010087
# ps010088
# ps010089
# ps010090
# PS010091
# PS010092
#
# Total participants in Time_OGTT_MMT: 89
# Participants with HFMM CGM data: 37
# Participants missing HFMM CGM data: 52
#
# Participants in Time_OGTT_MMT but not in final output:
# {'Ex35', 'Ex11', 'Ex91', 'Ex50', 'Ex76', 'Ex51', 'Ex32', 'Ex45', 'Ex39', 'Ex03', 'Ex14', 'Ex82', 'Ex12', 'Ex09', 'Ex66', 'Ex05', 'Ex44', 'Ex15', 'Ex92', 'Ex73', 'Ex86', 'Ex04', 'Ex74', 'Ex07', 'Ex18', 'Ex43', 'Ex55', 'Ex90', 'Ex28', 'Ex78', 'Ex70', 'Ex65', 'Ex64', 'Ex29', 'Ex25', 'Ex62', 'Ex88', 'Ex85', 'Ex89', 'Ex42', 'Ex87', 'Ex83', 'Ex10', 'Ex60', 'Ex71', 'Ex58', 'Ex61', 'Ex63', 'Ex84', 'Ex69', 'Ex48', 'Ex81'}

# %%
# DataFrame from the processed data
output_df = pd.DataFrame(processed_data)

# %%
# Sort DataFrame by ID and time
output_df = output_df.sort_values(['ID', 'time'])

# %%
# Save to CSV
output_df.to_csv('processed_cgm_data.csv', index=False)
print("Processed data saved to processed_cgm_data.csv")
# Out:
# Processed data saved to processed_cgm_data.csv

# %%
def extract_last_two(id_string):
    return re.search(r'\d+', id_string).group()[-2:].zfill(2)

# %%
ogtt_ids = set(extract_last_two(id) for id in time_ogtt['c11_rand_nr'])
processed_ids = set(id[2:] for id in output_df['ID'])  # Remove 'Ex' prefix
missing_ids = ogtt_ids - processed_ids

print("Sample OGTT IDs:", list(ogtt_ids)[:5])
print("Sample Processed IDs:", list(processed_ids)[:5])
print("Number of OGTT IDs:", len(ogtt_ids))
print("Number of Processed IDs:", len(processed_ids))
print("Number of Missing IDs:", len(missing_ids))

if missing_ids:
    print("\nMissing IDs (last two digits):")
    print(missing_ids)
    
    # To get full original IDs of missing entries
    missing_full_ids = [id for id in time_ogtt['c11_rand_nr'] if extract_last_two(id) in missing_ids]
    print("\nMissing full IDs:")
    print(missing_full_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ogtt_ids = set(extract_last_two(id) for id in time_ogtt['c11_rand_nr'])
#       2 processed_ids = set(id[2:] for id in output_df['ID'])  # Remove 'Ex' prefix
#       3 missing_ids = ogtt_ids - processed_ids
#
# NameError: name 'time_ogtt' is not defined

# %% [markdown]
# **Note:** I tried to implement a method of comparison between the c12_date and c13_date as the c13 date typically was 4-5 days later however the date formatting is inconsistent between the two for many entries.
