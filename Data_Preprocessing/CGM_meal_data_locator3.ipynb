# %% [markdown]
# So this file is for getting the relevant CGM data range of values that fall within the measurement window for OGTT, HFMM etc.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from collections import defaultdict
import re
# Out:
# C:\Users\paulo\AppData\Local\Temp\ipykernel_14872\981927567.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def simplify_id(id_string):
    # Extract the numeric part
    num_part = re.search(r'\d+', id_string).group()
    # Remove leading zeros
    simplified_num = str(int(num_part))
    # Keep only the last two digits (or one if it's a single digit)
    simplified_num = simplified_num[-2:] if len(simplified_num) > 1 else simplified_num
    return f"Ex{simplified_num}"

# %%
def parse_date_flexible(date_string):
    date_formats = ['%m/%d/%Y', '%d/%m/%Y']
    for fmt in date_formats:
        try:
            return datetime.strptime(date_string, fmt)
        except ValueError:
            continue
    raise ValueError(f"Unable to parse date: {date_string}")

# %%
def is_date_ambiguous(date_obj):
    return date_obj.day <= 12

# %%
def get_alternate_date(date_obj):
    try:
        return date_obj.replace(month=date_obj.day, day=date_obj.month)
    except ValueError:
        return None  # Return None if the alternate date is invalid

# %%
# Read the input files
time_ogtt = pd.read_csv('updated_Time_OGTT_MMT.csv')
cgm_data = pd.read_csv('CGM_Data_Table.csv')

# %%
# Convert timestamp columns to datetime
time_ogtt['c12_date'] = pd.to_datetime(time_ogtt['c12_date'].apply(parse_date_flexible))
time_ogtt['c12_OGTT_startdrink'] = pd.to_datetime(time_ogtt['c12_date'].dt.strftime('%Y-%m-%d') + ' ' + time_ogtt['c12_OGTT_startdrink'], format='%Y-%m-%d %I:%M:%S %p')
time_ogtt['c12_OGTT_act120'] = pd.to_datetime(time_ogtt['c12_date'].dt.strftime('%Y-%m-%d') + ' ' + time_ogtt['c12_OGTT_act120'], format='%Y-%m-%d %I:%M:%S %p')
cgm_data['Timestamp'] = pd.to_datetime(cgm_data['Timestamp'])

# %%
# empty list to store the processed data
processed_data = []
ambiguous_dates_list = []
ambiguous_dates_with_data = defaultdict(list)

# %%
# Process each participant
for _, row in time_ogtt.iterrows():
    participant_id = row['c11_rand_nr']
    ogtt_date = row['c12_date']
    start_time = row['c12_OGTT_startdrink']
    end_time = row['c12_OGTT_act120']

    print(f"Processing ID: {participant_id}, OGTT Date: {ogtt_date.date()}")

    # Check for ambiguous dates
    if is_date_ambiguous(ogtt_date):
        alt_date = get_alternate_date(ogtt_date)
        if alt_date:
            ambiguous_dates_list.append((participant_id, ogtt_date.strftime('%m/%d/%Y'), [ogtt_date, alt_date]))
            print(f"Ambiguous date for ID {participant_id}: {ogtt_date.strftime('%m/%d/%Y')}")
            print(f"  Interpretation 1: {ogtt_date.strftime('%Y-%m-%d')}")
            print(f"  Interpretation 2: {alt_date.strftime('%Y-%m-%d')}")
            
            # Check CGM data for both interpretations
            cgm_data_available = []
            for date in [ogtt_date, alt_date]:
                cgm_for_date = cgm_data[
                    (cgm_data['Participant'] == participant_id) &
                    (cgm_data['Timestamp'].dt.date == date.date())
                ]
                cgm_count = len(cgm_for_date)
                print(f"  CGM readings for {date.strftime('%Y-%m-%d')}: {cgm_count}")
                if cgm_count > 0:
                    cgm_data_available.append(date)
            
            # Record if both dates have CGM data
            if len(cgm_data_available) == 2:
                ambiguous_dates_with_data[participant_id].append({
                    'original_date': ogtt_date.strftime('%m/%d/%Y'),
                    'interpretation1': ogtt_date.strftime('%Y-%m-%d'),
                    'interpretation2': alt_date.strftime('%Y-%m-%d'),
                    'cgm_count1': len(cgm_data[(cgm_data['Participant'] == participant_id) & (cgm_data['Timestamp'].dt.date == ogtt_date.date())]),
                    'cgm_count2': len(cgm_data[(cgm_data['Participant'] == participant_id) & (cgm_data['Timestamp'].dt.date == alt_date.date())])
                })

    # Simplify the ID
    simplified_id = simplify_id(participant_id)

    # Filter CGM data for this participant and time window
    participant_cgm = cgm_data[
        (cgm_data['Participant'] == participant_id) &
        (cgm_data['Timestamp'] >= start_time) &
        (cgm_data['Timestamp'] <= end_time)
    ]

    print(f"ID {participant_id}: {len(participant_cgm)} CGM readings")

    # Process each CGM reading
    for _, cgm_row in participant_cgm.iterrows():
        time_diff = (cgm_row['Timestamp'] - start_time).total_seconds() / 60  # Convert to minutes
        processed_data.append({
            'ID': simplified_id,
            'Condition': np.nan,
            'test': 'CGM',
            'metab': 'gluc',
            'VAL': cgm_row['Sensor Glucose (mmol/L)'],
            'time': round(time_diff)  # Rounding to nearest minute
        })

# Create a DataFrame from the processed data
output_df = pd.DataFrame(processed_data)

# Sort the DataFrame by ID and time
output_df = output_df.sort_values(['ID', 'time'])

output_df.to_csv('processed_cgm_data.csv', index=False)
print("Processed data saved to processed_cgm_data.csv")

# Report on ambiguous dates
print("\nAmbiguous dates with CGM data for both interpretations:")
for participant_id, dates in ambiguous_dates_with_data.items():
    print(f"Participant ID: {participant_id}")
    for date_info in dates:
        print(f"  Original date: {date_info['original_date']}")
        print(f"    Interpretation 1: {date_info['interpretation1']} (CGM readings: {date_info['cgm_count1']})")
        print(f"    Interpretation 2: {date_info['interpretation2']} (CGM readings: {date_info['cgm_count2']})")
    print()

# Save ambiguous dates
# ambiguous_dates_df = pd.DataFrame([
#     {
#         'Participant_ID': pid,
#         'Original_Date': date_info['original_date'],
#         'Interpretation1': date_info['interpretation1'],
#         'CGM_Count1': date_info['cgm_count1'],
#         'Interpretation2': date_info['interpretation2'],
#         'CGM_Count2': date_info['cgm_count2']
#     }
#     for pid, dates in ambiguous_dates_with_data.items()
#     for date_info in dates
# ])
# ambiguous_dates_df.to_csv('ambiguous_dates_with_data.csv', index=False)
# print("Ambiguous dates with CGM data saved to 'ambiguous_dates_with_data.csv'")
# Out:
# Processing ID: PS010001, OGTT Date: 2018-07-18
# ID PS010001: 24 CGM readings
# Processing ID: PS010002, OGTT Date: 2019-01-25
# ID PS010002: 24 CGM readings
# Processing ID: PS010003, OGTT Date: 2018-09-21
# ID PS010003: 24 CGM readings
# Processing ID: PS010004, OGTT Date: 2018-09-07
# Ambiguous date for ID PS010004: 09/07/2018
#   Interpretation 1: 2018-09-07
#   Interpretation 2: 2018-07-09
#   CGM readings for 2018-09-07: 288
#   CGM readings for 2018-07-09: 0
# ID PS010004: 24 CGM readings
# Processing ID: PS010005, OGTT Date: 2018-08-31
# ID PS010005: 24 CGM readings
# Processing ID: PS010007, OGTT Date: 2018-10-25
# ID PS010007: 0 CGM readings
# Processing ID: PS010006, OGTT Date: 2018-10-19
# ID PS010006: 24 CGM readings
# Processing ID: PS010008, OGTT Date: 2018-10-18
# ID PS010008: 25 CGM readings
# Processing ID: PS010010, OGTT Date: 2018-11-08
# Ambiguous date for ID PS010010: 11/08/2018
#   Interpretation 1: 2018-11-08
#   Interpretation 2: 2018-08-11
#   CGM readings for 2018-11-08: 288
#   CGM readings for 2018-08-11: 0
# ID PS010010: 24 CGM readings
# Processing ID: PS010009, OGTT Date: 2018-10-30
# ID PS010009: 24 CGM readings
# Processing ID: PS010012, OGTT Date: 2018-11-23
# ID PS010012: 24 CGM readings
# Processing ID: PS010014, OGTT Date: 2019-01-11
# Ambiguous date for ID PS010014: 01/11/2019
#   Interpretation 1: 2019-01-11
#   Interpretation 2: 2019-11-01
#   CGM readings for 2019-01-11: 288
#   CGM readings for 2019-11-01: 0
# ID PS010014: 25 CGM readings
# Processing ID: PS010011, OGTT Date: 2018-11-30
# ID PS010011: 24 CGM readings
# Processing ID: PS010013, OGTT Date: 2019-01-11
# Ambiguous date for ID PS010013: 01/11/2019
#   Interpretation 1: 2019-01-11
#   Interpretation 2: 2019-11-01
#   CGM readings for 2019-01-11: 193
#   CGM readings for 2019-11-01: 0
# ID PS010013: 24 CGM readings
# Processing ID: PS010043, OGTT Date: 2019-11-08
# Ambiguous date for ID PS010043: 11/08/2019
#   Interpretation 1: 2019-11-08
#   Interpretation 2: 2019-08-11
#   CGM readings for 2019-11-08: 288
#   CGM readings for 2019-08-11: 0
# ID PS010043: 24 CGM readings
# Processing ID: PS010015, OGTT Date: 2019-01-31
# ID PS010015: 0 CGM readings
# Processing ID: PS010017, OGTT Date: 2019-02-13
# ID PS010017: 24 CGM readings
# Processing ID: PS010016, OGTT Date: 2019-02-15
# ID PS010016: 24 CGM readings
# Processing ID: PS010018, OGTT Date: 2019-03-29
# ID PS010018: 24 CGM readings
# Processing ID: PS010019, OGTT Date: 2019-03-14
# ID PS010019: 23 CGM readings
# Processing ID: PS010020, OGTT Date: 2019-03-22
# ID PS010020: 25 CGM readings
# Processing ID: PS010045, OGTT Date: 2019-11-08
# Ambiguous date for ID PS010045: 11/08/2019
#   Interpretation 1: 2019-11-08
#   Interpretation 2: 2019-08-11
#   CGM readings for 2019-11-08: 288
#   CGM readings for 2019-08-11: 0
# ID PS010045: 25 CGM readings
# Processing ID: PS010031, OGTT Date: 2019-06-21
# ID PS010031: 24 CGM readings
# Processing ID: PS010021, OGTT Date: 2019-04-18
# ID PS010021: 25 CGM readings
# Processing ID: PS010022, OGTT Date: 2019-05-10
# Ambiguous date for ID PS010022: 05/10/2019
#   Interpretation 1: 2019-05-10
#   Interpretation 2: 2019-10-05
#   CGM readings for 2019-05-10: 288
#   CGM readings for 2019-10-05: 0
# ID PS010022: 25 CGM readings
# Processing ID: PS010076, OGTT Date: 2020-10-01
# Ambiguous date for ID PS010076: 10/01/2020
#   Interpretation 1: 2020-10-01
#   Interpretation 2: 2020-01-10
#   CGM readings for 2020-10-01: 288
#   CGM readings for 2020-01-10: 0
# ID PS010076: 24 CGM readings
# Processing ID: PS010024, OGTT Date: 2019-05-09
# Ambiguous date for ID PS010024: 05/09/2019
#   Interpretation 1: 2019-05-09
#   Interpretation 2: 2019-09-05
#   CGM readings for 2019-05-09: 288
#   CGM readings for 2019-09-05: 0
# ID PS010024: 24 CGM readings
# Processing ID: PS010023, OGTT Date: 2019-05-03
# Ambiguous date for ID PS010023: 05/03/2019
#   Interpretation 1: 2019-05-03
#   Interpretation 2: 2019-03-05
#   CGM readings for 2019-05-03: 288
#   CGM readings for 2019-03-05: 0
# ID PS010023: 24 CGM readings
# Processing ID: PS010028, OGTT Date: 2019-06-21
# ID PS010028: 24 CGM readings
# Processing ID: PS010027, OGTT Date: 2019-06-20
# ID PS010027: 24 CGM readings
# Processing ID: PS010030, OGTT Date: 2019-07-11
# Ambiguous date for ID PS010030: 07/11/2019
#   Interpretation 1: 2019-07-11
#   Interpretation 2: 2019-11-07
#   CGM readings for 2019-07-11: 288
#   CGM readings for 2019-11-07: 0
# ID PS010030: 24 CGM readings
# Processing ID: PS010025, OGTT Date: 2019-06-05
# Ambiguous date for ID PS010025: 06/05/2019
#   Interpretation 1: 2019-06-05
#   Interpretation 2: 2019-05-06
#   CGM readings for 2019-06-05: 288
#   CGM readings for 2019-05-06: 0
# ID PS010025: 25 CGM readings
# Processing ID: PS010032, OGTT Date: 2019-07-05
# Ambiguous date for ID PS010032: 07/05/2019
#   Interpretation 1: 2019-07-05
#   Interpretation 2: 2019-05-07
#   CGM readings for 2019-07-05: 288
#   CGM readings for 2019-05-07: 0
# ID PS010032: 24 CGM readings
# Processing ID: PS010047, OGTT Date: 2019-11-15
# ID PS010047: 24 CGM readings
# Processing ID: PS010026, OGTT Date: 2019-09-13
# ID PS010026: 24 CGM readings
# Processing ID: PS010035, OGTT Date: 2019-07-27
# ID PS010035: 0 CGM readings
# Processing ID: PS010034, OGTT Date: 2019-07-19
# ID PS010034: 25 CGM readings
# Processing ID: PS010029, OGTT Date: 2019-09-06
# Ambiguous date for ID PS010029: 09/06/2019
#   Interpretation 1: 2019-09-06
#   Interpretation 2: 2019-06-09
#   CGM readings for 2019-09-06: 288
#   CGM readings for 2019-06-09: 0
# ID PS010029: 25 CGM readings
# Processing ID: PS010033, OGTT Date: 2019-07-11
# Ambiguous date for ID PS010033: 07/11/2019
#   Interpretation 1: 2019-07-11
#   Interpretation 2: 2019-11-07
#   CGM readings for 2019-07-11: 288
#   CGM readings for 2019-11-07: 0
# ID PS010033: 24 CGM readings
# Processing ID: PS010046, OGTT Date: 2019-11-15
# ID PS010046: 24 CGM readings
# Processing ID: PS010039, OGTT Date: 2019-08-23
# ID PS010039: 24 CGM readings
# Processing ID: PS010036, OGTT Date: 2019-08-16
# ID PS010036: 25 CGM readings
# Processing ID: PS010037, OGTT Date: 2019-10-18
# ID PS010037: 25 CGM readings
# Processing ID: PS010037, OGTT Date: 2019-09-06
# Ambiguous date for ID PS010037: 09/06/2019
#   Interpretation 1: 2019-09-06
#   Interpretation 2: 2019-06-09
#   CGM readings for 2019-09-06: 0
#   CGM readings for 2019-06-09: 0
# ID PS010037: 0 CGM readings
# Processing ID: PS010040, OGTT Date: 2019-09-25
# ID PS010040: 24 CGM readings
# Processing ID: PS010041, OGTT Date: 2019-10-11
# Ambiguous date for ID PS010041: 10/11/2019
#   Interpretation 1: 2019-10-11
#   Interpretation 2: 2019-11-10
#   CGM readings for 2019-10-11: 288
#   CGM readings for 2019-11-10: 0
# ID PS010041: 24 CGM readings
# Processing ID: PS010042, OGTT Date: 2019-10-17
# ID PS010042: 24 CGM readings
# Processing ID: PS010044, OGTT Date: 2019-11-15
# ID PS010044: 0 CGM readings
# Processing ID: PS010049, OGTT Date: 2019-11-21
# ID PS010049: 24 CGM readings
# Processing ID: PS010048, OGTT Date: 2019-11-01
# Ambiguous date for ID PS010048: 11/01/2019
#   Interpretation 1: 2019-11-01
#   Interpretation 2: 2019-01-11
#   CGM readings for 2019-11-01: 288
#   CGM readings for 2019-01-11: 0
# ID PS010048: 25 CGM readings
# Processing ID: PS010052, OGTT Date: 2019-11-22
# ID PS010052: 24 CGM readings
# Processing ID: PS010050, OGTT Date: 2019-11-29
# ID PS010050: 25 CGM readings
# Processing ID: PS010057, OGTT Date: 2020-01-10
# Ambiguous date for ID PS010057: 01/10/2020
#   Interpretation 1: 2020-01-10
#   Interpretation 2: 2020-10-01
#   CGM readings for 2020-01-10: 288
#   CGM readings for 2020-10-01: 0
# ID PS010057: 24 CGM readings
# Processing ID: PS010075, OGTT Date: 2020-09-11
# Ambiguous date for ID PS010075: 09/11/2020
#   Interpretation 1: 2020-09-11
#   Interpretation 2: 2020-11-09
#   CGM readings for 2020-09-11: 288
#   CGM readings for 2020-11-09: 0
# ID PS010075: 24 CGM readings
# Processing ID: PS010053, OGTT Date: 2019-12-13
# ID PS010053: 24 CGM readings
# Processing ID: PS010074, OGTT Date: 2020-08-28
# ID PS010074: 24 CGM readings
# Processing ID: PS010054, OGTT Date: 2019-12-13
# ID PS010054: 24 CGM readings
# Processing ID: PS010055, OGTT Date: 2019-11-29
# ID PS010055: 24 CGM readings
# Processing ID: PS010062, OGTT Date: 2020-01-23
# ID PS010062: 24 CGM readings
# Processing ID: PS010064, OGTT Date: 2020-01-31
# ID PS010064: 25 CGM readings
# Processing ID: PS010058, OGTT Date: 2020-01-17
# ID PS010058: 24 CGM readings
# Processing ID: PS010060 , OGTT Date: 2020-01-24
# ID PS010060 : 0 CGM readings
# Processing ID: PS010061, OGTT Date: 2020-01-31
# ID PS010061: 24 CGM readings
# Processing ID: PS010065, OGTT Date: 2020-01-31
# ID PS010065: 24 CGM readings
# Processing ID: PS010063 , OGTT Date: 2020-01-17
# ID PS010063 : 0 CGM readings
# Processing ID: PS010066 , OGTT Date: 2020-03-12
# Ambiguous date for ID PS010066 : 03/12/2020
#   Interpretation 1: 2020-03-12
#   Interpretation 2: 2020-12-03
#   CGM readings for 2020-03-12: 0
#   CGM readings for 2020-12-03: 0
# ID PS010066 : 0 CGM readings
# Processing ID: PS010067, OGTT Date: 2020-02-28
# ID PS010067: 24 CGM readings
# Processing ID: PS010068, OGTT Date: 2020-02-14
# ID PS010068: 24 CGM readings
# Processing ID: PS010070, OGTT Date: 2020-03-13
# ID PS010070: 24 CGM readings
# Processing ID: PS010069, OGTT Date: 2020-02-21
# ID PS010069: 24 CGM readings
# Processing ID: PS010071, OGTT Date: 2020-08-07
# Ambiguous date for ID PS010071: 08/07/2020
#   Interpretation 1: 2020-08-07
#   Interpretation 2: 2020-07-08
#   CGM readings for 2020-08-07: 288
#   CGM readings for 2020-07-08: 0
# ID PS010071: 24 CGM readings
# Processing ID: PS010072, OGTT Date: 2020-08-14
# ID PS010072: 24 CGM readings
# Processing ID: PS010073, OGTT Date: 2020-08-21
# ID PS010073: 24 CGM readings
# Processing ID: PS010077, OGTT Date: 2020-09-25
# ID PS010077: 24 CGM readings
# Processing ID: PS010080, OGTT Date: 2020-11-12
# Ambiguous date for ID PS010080: 11/12/2020
#   Interpretation 1: 2020-11-12
#   Interpretation 2: 2020-12-11
#   CGM readings for 2020-11-12: 288
#   CGM readings for 2020-12-11: 0
# ID PS010080: 24 CGM readings
# Processing ID: PS010081, OGTT Date: 2020-10-09
# Ambiguous date for ID PS010081: 10/09/2020
#   Interpretation 1: 2020-10-09
#   Interpretation 2: 2020-09-10
#   CGM readings for 2020-10-09: 288
#   CGM readings for 2020-09-10: 0
# ID PS010081: 24 CGM readings
# Processing ID: PS010078, OGTT Date: 2020-09-04
# Ambiguous date for ID PS010078: 09/04/2020
#   Interpretation 1: 2020-09-04
#   Interpretation 2: 2020-04-09
#   CGM readings for 2020-09-04: 288
#   CGM readings for 2020-04-09: 0
# ID PS010078: 24 CGM readings
# Processing ID: PS010079, OGTT Date: 2020-09-18
# ID PS010079: 24 CGM readings
# Processing ID: PS010082, OGTT Date: 2020-10-30
# ID PS010082: 24 CGM readings
# Processing ID: PS010083, OGTT Date: 2020-11-05
# Ambiguous date for ID PS010083: 11/05/2020
#   Interpretation 1: 2020-11-05
#   Interpretation 2: 2020-05-11
#   CGM readings for 2020-11-05: 288
#   CGM readings for 2020-05-11: 0
# ID PS010083: 24 CGM readings
# Processing ID: ps010085, OGTT Date: 2020-12-04
# Ambiguous date for ID ps010085: 12/04/2020
#   Interpretation 1: 2020-12-04
#   Interpretation 2: 2020-04-12
#   CGM readings for 2020-12-04: 0
#   CGM readings for 2020-04-12: 0
# ID ps010085: 0 CGM readings
# Processing ID: PS010084, OGTT Date: 2020-11-20
# ID PS010084: 24 CGM readings
# Processing ID: ps010086, OGTT Date: 2020-12-04
# Ambiguous date for ID ps010086: 12/04/2020
#   Interpretation 1: 2020-12-04
#   Interpretation 2: 2020-04-12
#   CGM readings for 2020-12-04: 0
#   CGM readings for 2020-04-12: 0
# ID ps010086: 0 CGM readings
# Processing ID: ps010087, OGTT Date: 2021-01-07
# Ambiguous date for ID ps010087: 01/07/2021
#   Interpretation 1: 2021-01-07
#   Interpretation 2: 2021-07-01
#   CGM readings for 2021-01-07: 0
#   CGM readings for 2021-07-01: 0
# ID ps010087: 0 CGM readings
# Processing ID: ps010088, OGTT Date: 2020-12-11
# Ambiguous date for ID ps010088: 12/11/2020
#   Interpretation 1: 2020-12-11
#   Interpretation 2: 2020-11-12
#   CGM readings for 2020-12-11: 0
#   CGM readings for 2020-11-12: 0
# ID ps010088: 0 CGM readings
# Processing ID: ps010089, OGTT Date: 2021-01-15
# ID ps010089: 0 CGM readings
# Processing ID: ps010090, OGTT Date: 2021-01-08
# Ambiguous date for ID ps010090: 01/08/2021
#   Interpretation 1: 2021-01-08
#   Interpretation 2: 2021-08-01
#   CGM readings for 2021-01-08: 0
#   CGM readings for 2021-08-01: 0
# ID ps010090: 0 CGM readings
# Processing ID: PS010091, OGTT Date: 2021-02-05
# Ambiguous date for ID PS010091: 02/05/2021
#   Interpretation 1: 2021-02-05
#   Interpretation 2: 2021-05-02
#   CGM readings for 2021-02-05: 288
#   CGM readings for 2021-05-02: 288
# ID PS010091: 24 CGM readings
# Processing ID: PS010092, OGTT Date: 2021-02-05
# Ambiguous date for ID PS010092: 02/05/2021
#   Interpretation 1: 2021-02-05
#   Interpretation 2: 2021-05-02
#   CGM readings for 2021-02-05: 288
#   CGM readings for 2021-05-02: 0
# ID PS010092: 24 CGM readings
# Processed data saved to processed_cgm_data.csv
#
# Ambiguous dates with CGM data for both interpretations:
# Participant ID: PS010091
#   Original date: 02/05/2021
#     Interpretation 1: 2021-02-05 (CGM readings: 288)
#     Interpretation 2: 2021-05-02 (CGM readings: 288)
#
# Ambiguous dates with CGM data saved to 'ambiguous_dates_with_data.csv'
#
# IDs in OGTT data but not in final output:
# {'PS010009', 'PS010030', 'PS010053', 'PS010012', 'PS010025', 'PS010008', 'PS010019', 'PS010068', 'PS010077', 'PS010048', 'PS010092', 'PS010016', 'PS010026', 'PS010029', 'ps010085', 'PS010067', 'PS010063 ', 'PS010091', 'PS010045', 'PS010027', 'PS010015', 'PS010037', 'PS010064', 'ps010088', 'PS010020', 'PS010004', 'PS010081', 'PS010062', 'ps010089', 'PS010054', 'PS010046', 'PS010036', 'PS010071', 'PS010031', 'PS010043', 'PS010018', 'PS010073', 'PS010001', 'PS010017', 'PS010084', 'PS010040', 'PS010076', 'ps010090', 'PS010075', 'PS010023', 'PS010005', 'PS010021', 'PS010079', 'PS010024', 'PS010033', 'PS010050', 'PS010061', 'PS010041', 'PS010044', 'PS010047', 'PS010074', 'PS010032', 'PS010002', 'PS010022', 'PS010078', 'PS010072', 'PS010052', 'PS010049', 'PS010080', 'PS010006', 'PS010039', 'PS010065', 'PS010013', 'ps010086', 'PS010069', 'ps010087', 'PS010058', 'PS010034', 'PS010070', 'PS010010', 'PS010060 ', 'PS010035', 'PS010011', 'PS010055', 'PS010066 ', 'PS010042', 'PS010028', 'PS010003', 'PS010007', 'PS010057', 'PS010014', 'PS010082', 'PS010083'}

# %%
# DataFrame from the processed data
output_df = pd.DataFrame(processed_data)

# %%
# Sort DataFrame by ID and time
output_df = output_df.sort_values(['ID', 'time'])

# %%
# Save to CSV
output_df.to_csv('processed_cgm_data.csv', index=False)
print("Processed data saved to processed_cgm_data.csv")
# Out:
# Processed data saved to processed_cgm_data.csv

# %%
def extract_last_two(id_string):
    return re.search(r'\d+', id_string).group()[-2:].zfill(2)

# %%
ogtt_ids = set(extract_last_two(id) for id in time_ogtt['c11_rand_nr'])
processed_ids = set(id[2:] for id in output_df['ID'])  # Remove 'Ex' prefix
missing_ids = ogtt_ids - processed_ids

print("Sample OGTT IDs:", list(ogtt_ids)[:5])
print("Sample Processed IDs:", list(processed_ids)[:5])
print("Number of OGTT IDs:", len(ogtt_ids))
print("Number of Processed IDs:", len(processed_ids))
print("Number of Missing IDs:", len(missing_ids))

if missing_ids:
    print("\nMissing IDs (last two digits):")
    print(missing_ids)
    
    # To get full original IDs of missing entries
    missing_full_ids = [id for id in time_ogtt['c11_rand_nr'] if extract_last_two(id) in missing_ids]
    print("\nMissing full IDs:")
    print(missing_full_ids)
# Out:
# Sample OGTT IDs: ['29', '63', '10', '86', '14']
# Sample Processed IDs: ['53', '19', '62', '71', '52']
# Number of OGTT IDs: 88
# Number of Processed IDs: 75
# Number of Missing IDs: 13
#
# Missing IDs (last two digits):
# {'86', '87', '85', '60', '44', '15', '90', '88', '89', '63', '07', '35', '66'}
#
# Missing full IDs:
# ['PS010007', 'PS010015', 'PS010035', 'PS010044', 'PS010060 ', 'PS010063 ', 'PS010066 ', 'ps010085', 'ps010086', 'ps010087', 'ps010088', 'ps010089', 'ps010090']

# %% [markdown]
# **Note:** I tried to implement a method of comparison between the c12_date and c13_date as the c13 date typically was 4-5 days later however the date formatting is inconsistent between the two for many entries.
